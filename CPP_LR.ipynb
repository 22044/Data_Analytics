# %% [markdown]
# <a href="https://colab.research.google.com/github/harshil1030/Data_Analytics/blob/main/CPP_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error

# %%
data=pd.read_csv('/content/drive/MyDrive/Capstone-Project-1/final.csv')
print(f'''number of rows - {data.shape[0]}
number of columns - {data.shape[1]}''')
# Out:
# number of rows - 19974
# number of columns - 14

# %%
def null_count():
    return pd.DataFrame({'features': data.columns,
                'dtypes': data.dtypes.values,
                'NaN count': data.isnull().sum().values,
                'NaN percentage': data.isnull().sum().values/data.shape[0]}).style.background_gradient(cmap='Blues',low=0.1,high=0.01)
null_count()
# Out:
# <style type="text/css">
# #T_3d68a_row0_col2, #T_3d68a_row0_col3, #T_3d68a_row1_col2, #T_3d68a_row1_col3, #T_3d68a_row3_col2, #T_3d68a_row3_col3, #T_3d68a_row4_col2, #T_3d68a_row4_col3, #T_3d68a_row5_col2, #T_3d68a_row5_col3, #T_3d68a_row6_col2, #T_3d68a_row6_col3, #T_3d68a_row7_col2, #T_3d68a_row7_col3, #T_3d68a_row8_col2, #T_3d68a_row8_col3, #T_3d68a_row13_col2, #T_3d68a_row13_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_3d68a_row2_col2, #T_3d68a_row2_col3 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_3d68a_row9_col2, #T_3d68a_row9_col3 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_3d68a_row10_col2, #T_3d68a_row10_col3 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_3d68a_row11_col2, #T_3d68a_row11_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_3d68a_row12_col2, #T_3d68a_row12_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_3d68a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >features</th>
#       <th class="col_heading level0 col1" >dtypes</th>
#       <th class="col_heading level0 col2" >NaN count</th>
#       <th class="col_heading level0 col3" >NaN percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d68a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d68a_row0_col0" class="data row0 col0" >full_name</td>
#       <td id="T_3d68a_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_3d68a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_3d68a_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d68a_row1_col0" class="data row1 col0" >selling_price</td>
#       <td id="T_3d68a_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_3d68a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_3d68a_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d68a_row2_col0" class="data row2 col0" >new_price</td>
#       <td id="T_3d68a_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_3d68a_row2_col2" class="data row2 col2" >10410</td>
#       <td id="T_3d68a_row2_col3" class="data row2 col3" >0.521178</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d68a_row3_col0" class="data row3 col0" >year</td>
#       <td id="T_3d68a_row3_col1" class="data row3 col1" >int64</td>
#       <td id="T_3d68a_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_3d68a_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d68a_row4_col0" class="data row4 col0" >seller_type</td>
#       <td id="T_3d68a_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_3d68a_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_3d68a_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d68a_row5_col0" class="data row5 col0" >km_driven</td>
#       <td id="T_3d68a_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_3d68a_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_3d68a_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d68a_row6_col0" class="data row6 col0" >owner_type</td>
#       <td id="T_3d68a_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_3d68a_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_3d68a_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d68a_row7_col0" class="data row7 col0" >fuel_type</td>
#       <td id="T_3d68a_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_3d68a_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_3d68a_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d68a_row8_col0" class="data row8 col0" >transmission_type</td>
#       <td id="T_3d68a_row8_col1" class="data row8 col1" >object</td>
#       <td id="T_3d68a_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_3d68a_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d68a_row9_col0" class="data row9 col0" >mileage</td>
#       <td id="T_3d68a_row9_col1" class="data row9 col1" >object</td>
#       <td id="T_3d68a_row9_col2" class="data row9 col2" >160</td>
#       <td id="T_3d68a_row9_col3" class="data row9 col3" >0.008010</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3d68a_row10_col0" class="data row10 col0" >engine</td>
#       <td id="T_3d68a_row10_col1" class="data row10 col1" >object</td>
#       <td id="T_3d68a_row10_col2" class="data row10 col2" >110</td>
#       <td id="T_3d68a_row10_col3" class="data row10 col3" >0.005507</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3d68a_row11_col0" class="data row11 col0" >max_power</td>
#       <td id="T_3d68a_row11_col1" class="data row11 col1" >object</td>
#       <td id="T_3d68a_row11_col2" class="data row11 col2" >337</td>
#       <td id="T_3d68a_row11_col3" class="data row11 col3" >0.016872</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3d68a_row12_col0" class="data row12 col0" >seats</td>
#       <td id="T_3d68a_row12_col1" class="data row12 col1" >object</td>
#       <td id="T_3d68a_row12_col2" class="data row12 col2" >87</td>
#       <td id="T_3d68a_row12_col3" class="data row12 col3" >0.004356</td>
#     </tr>
#     <tr>
#       <th id="T_3d68a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3d68a_row13_col0" class="data row13 col0" >company</td>
#       <td id="T_3d68a_row13_col1" class="data row13 col1" >object</td>
#       <td id="T_3d68a_row13_col2" class="data row13 col2" >15</td>
#       <td id="T_3d68a_row13_col3" class="data row13 col3" >0.000751</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(data.shape[0]):
    try:
        price = float(data['selling_price'][i].split(' ')[0])
        digit = data['selling_price'][i].split(' ')[1]
        if digit == 'Lakh*':
            price = price * 100000
            data['selling_price'][i] = price
        elif digit == 'Cr*':
            price = price * 10000000
            data['selling_price'][i] = price
    except:
        price = data['selling_price'][i][:-1]
        price = price.replace(',', '')
        data['selling_price'][i] = float(price)
# Out:
# <ipython-input-269-9213b294f096>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['selling_price'][i] = price
# <ipython-input-269-9213b294f096>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['selling_price'][i] = float(price)
# <ipython-input-269-9213b294f096>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['selling_price'][i] = price

# %%
data['full_name']=data['full_name'].str.split(' ').str.slice(0,3).str.join(' ')
data['km_driven'] = data['km_driven'].str.split(' ', n=1, expand=True)[0]
data['km_driven'] = data['km_driven'].str.replace(',','')
data['km_driven']=data['km_driven'].astype(int)
data['selling_price'] = data['selling_price'].apply(np.int64)
#data['mileage'] = data['mileage'].str.split(' ', expand=True)[0].str.split('e', expand=True)[2]
#data['engine'] = data['engine'].str.split(' ', expand=True)[0].str.split('e',expand=True)[1]
#data['max_power'] = data['max_power'].str.split(' ', expand=True)[1].str.split('r',expand=True)[1]
#data['seats'] = data['seats'].str.split('s', expand=True)[1]

# %%
data
# Out:
#                      full_name  selling_price  \
# 0              Maruti Alto Std         120000
# 1            Hyundai Grand i10         550000
# 2             Hyundai i20 Asta         215000
# 3              Maruti Alto K10         225999
# 4      Ford Ecosport 2015-2021         570000
# ...                        ...            ...
# 19969    Toyota Platinum Etios         650000
# 19970       Maruti Ertiga BSIV         925000
# 19971          Skoda Rapid 1.5         425000
# 19972       Mahindra XUV500 W6        1225000
# 19973        Honda City i-VTEC        1200000
#
#                                             new_price  year seller_type  \
# 0                                                 NaN  2012  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016  Individual
# 2                                                 NaN  2010  Individual
# 3                                                 NaN  2012  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015      Dealer
# ...                                               ...   ...         ...
# 19969                                             NaN  2017      Dealer
# 19970                                             NaN  2019      Dealer
# 19971                                             NaN  2015      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016      Dealer
# 19973                                             NaN  2019      Dealer
#
#        km_driven   owner_type fuel_type transmission_type            mileage  \
# 0         120000  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1          20000  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2          60000  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3          37000  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4          30000  First Owner    Diesel            Manual  Mileage22.77 kmpl
# ...          ...          ...       ...               ...                ...
# 19969      69480  First Owner    Diesel            Manual  Mileage23.59 kmpl
# 19970      18000  First Owner    Petrol            Manual   Mileage17.5 kmpl
# 19971      67000  First Owner    Diesel            Manual  Mileage21.14 kmpl
# 19972    3800000  First Owner    Diesel            Manual   Mileage16.0 kmpl
# 19973      13000  First Owner    Petrol         Automatic   Mileage18.0 kmpl
#
#               engine            max_power   seats  company
# 0       Engine796 CC    Max Power46.3 bhp  Seats5   Maruti
# 1      Engine1197 CC      Max Power82 bhp  Seats5  Hyundai
# 2      Engine1197 CC      Max Power80 bhp  Seats5  Hyundai
# 3       Engine998 CC    Max Power67.1 bhp  Seats5   Maruti
# 4      Engine1498 CC   Max Power98.59 bhp  Seats5     Ford
# ...              ...                  ...     ...      ...
# 19969  Engine1364 CC   Max Power67.05 bhp  Seats5      NaN
# 19970  Engine1373 CC    Max Power91.1 bhp  Seats7      NaN
# 19971  Engine1498 CC  Max Power103.52 bhp  Seats5      NaN
# 19972  Engine2179 CC     Max Power140 bhp  Seats7      NaN
# 19973  Engine1497 CC   Max Power117.6 bhp  Seats5      NaN
#
# [19974 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19974 entries, 0 to 19973
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          19974 non-null  object
#  1   selling_price      19974 non-null  int64
#  2   new_price          9564 non-null   object
#  3   year               19974 non-null  int64
#  4   seller_type        19974 non-null  object
#  5   km_driven          19974 non-null  int64
#  6   owner_type         19974 non-null  object
#  7   fuel_type          19974 non-null  object
#  8   transmission_type  19974 non-null  object
#  9   mileage            19814 non-null  object
#  10  engine             19864 non-null  object
#  11  max_power          19637 non-null  object
#  12  seats              19887 non-null  object
#  13  company            19959 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 2.1+ MB

# %%
data['full_name']
# Out:
# 0                Maruti Alto Std
# 1              Hyundai Grand i10
# 2               Hyundai i20 Asta
# 3                Maruti Alto K10
# 4        Ford Ecosport 2015-2021
#                   ...
# 19969      Toyota Platinum Etios
# 19970         Maruti Ertiga BSIV
# 19971            Skoda Rapid 1.5
# 19972         Mahindra XUV500 W6
# 19973          Honda City i-VTEC
# Name: full_name, Length: 19974, dtype: object

# %% [markdown]
# #Cleaning

# %%
backup=data.copy()

# %%
data
# Out:
#                      full_name  selling_price  \
# 0              Maruti Alto Std         120000
# 1            Hyundai Grand i10         550000
# 2             Hyundai i20 Asta         215000
# 3              Maruti Alto K10         225999
# 4      Ford Ecosport 2015-2021         570000
# ...                        ...            ...
# 19969    Toyota Platinum Etios         650000
# 19970       Maruti Ertiga BSIV         925000
# 19971          Skoda Rapid 1.5         425000
# 19972       Mahindra XUV500 W6        1225000
# 19973        Honda City i-VTEC        1200000
#
#                                             new_price  year seller_type  \
# 0                                                 NaN  2012  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016  Individual
# 2                                                 NaN  2010  Individual
# 3                                                 NaN  2012  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015      Dealer
# ...                                               ...   ...         ...
# 19969                                             NaN  2017      Dealer
# 19970                                             NaN  2019      Dealer
# 19971                                             NaN  2015      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016      Dealer
# 19973                                             NaN  2019      Dealer
#
#        km_driven   owner_type fuel_type transmission_type            mileage  \
# 0         120000  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1          20000  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2          60000  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3          37000  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4          30000  First Owner    Diesel            Manual  Mileage22.77 kmpl
# ...          ...          ...       ...               ...                ...
# 19969      69480  First Owner    Diesel            Manual  Mileage23.59 kmpl
# 19970      18000  First Owner    Petrol            Manual   Mileage17.5 kmpl
# 19971      67000  First Owner    Diesel            Manual  Mileage21.14 kmpl
# 19972    3800000  First Owner    Diesel            Manual   Mileage16.0 kmpl
# 19973      13000  First Owner    Petrol         Automatic   Mileage18.0 kmpl
#
#               engine            max_power   seats  company
# 0       Engine796 CC    Max Power46.3 bhp  Seats5   Maruti
# 1      Engine1197 CC      Max Power82 bhp  Seats5  Hyundai
# 2      Engine1197 CC      Max Power80 bhp  Seats5  Hyundai
# 3       Engine998 CC    Max Power67.1 bhp  Seats5   Maruti
# 4      Engine1498 CC   Max Power98.59 bhp  Seats5     Ford
# ...              ...                  ...     ...      ...
# 19969  Engine1364 CC   Max Power67.05 bhp  Seats5      NaN
# 19970  Engine1373 CC    Max Power91.1 bhp  Seats7      NaN
# 19971  Engine1498 CC  Max Power103.52 bhp  Seats5      NaN
# 19972  Engine2179 CC     Max Power140 bhp  Seats7      NaN
# 19973  Engine1497 CC   Max Power117.6 bhp  Seats5      NaN
#
# [19974 rows x 14 columns]

# %%
data=data.drop(['new_price', 'seller_type','owner_type','mileage','engine','max_power','seats'], axis=1)

# %%
data
# Out:
#                      full_name  selling_price  year  km_driven fuel_type  \
# 0              Maruti Alto Std         120000  2012     120000    Petrol
# 1            Hyundai Grand i10         550000  2016      20000    Petrol
# 2             Hyundai i20 Asta         215000  2010      60000    Petrol
# 3              Maruti Alto K10         225999  2012      37000    Petrol
# 4      Ford Ecosport 2015-2021         570000  2015      30000    Diesel
# ...                        ...            ...   ...        ...       ...
# 19969    Toyota Platinum Etios         650000  2017      69480    Diesel
# 19970       Maruti Ertiga BSIV         925000  2019      18000    Petrol
# 19971          Skoda Rapid 1.5         425000  2015      67000    Diesel
# 19972       Mahindra XUV500 W6        1225000  2016    3800000    Diesel
# 19973        Honda City i-VTEC        1200000  2019      13000    Petrol
#
#       transmission_type  company
# 0                Manual   Maruti
# 1                Manual  Hyundai
# 2                Manual  Hyundai
# 3                Manual   Maruti
# 4                Manual     Ford
# ...                 ...      ...
# 19969            Manual      NaN
# 19970            Manual      NaN
# 19971            Manual      NaN
# 19972            Manual      NaN
# 19973         Automatic      NaN
#
# [19974 rows x 7 columns]

# %%
data=data.reset_index(drop=True)

# %%
data
# Out:
#                      full_name  selling_price  year  km_driven fuel_type  \
# 0              Maruti Alto Std         120000  2012     120000    Petrol
# 1            Hyundai Grand i10         550000  2016      20000    Petrol
# 2             Hyundai i20 Asta         215000  2010      60000    Petrol
# 3              Maruti Alto K10         225999  2012      37000    Petrol
# 4      Ford Ecosport 2015-2021         570000  2015      30000    Diesel
# ...                        ...            ...   ...        ...       ...
# 19969    Toyota Platinum Etios         650000  2017      69480    Diesel
# 19970       Maruti Ertiga BSIV         925000  2019      18000    Petrol
# 19971          Skoda Rapid 1.5         425000  2015      67000    Diesel
# 19972       Mahindra XUV500 W6        1225000  2016    3800000    Diesel
# 19973        Honda City i-VTEC        1200000  2019      13000    Petrol
#
#       transmission_type  company
# 0                Manual   Maruti
# 1                Manual  Hyundai
# 2                Manual  Hyundai
# 3                Manual   Maruti
# 4                Manual     Ford
# ...                 ...      ...
# 19969            Manual      NaN
# 19970            Manual      NaN
# 19971            Manual      NaN
# 19972            Manual      NaN
# 19973         Automatic      NaN
#
# [19974 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19974 entries, 0 to 19973
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          19974 non-null  object
#  1   selling_price      19974 non-null  int64
#  2   year               19974 non-null  int64
#  3   km_driven          19974 non-null  int64
#  4   fuel_type          19974 non-null  object
#  5   transmission_type  19974 non-null  object
#  6   company            19959 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
data.describe() # 2014-2021
# Out:
#        selling_price          year     km_driven
# count   1.997400e+04  19974.000000  1.997400e+04
# mean    7.392944e+05   2014.526134  5.823889e+04
# std     9.104001e+05      3.248791  5.172760e+04
# min     2.500000e+04   1991.000000  1.000000e+02
# 25%     3.400000e+05   2013.000000  3.111400e+04
# 50%     5.200000e+05   2015.000000  5.200000e+04
# 75%     7.850000e+05   2017.000000  7.400000e+04
# max     3.950000e+07   2021.000000  3.800000e+06

# %%
data
# Out:
#                      full_name  selling_price  year  km_driven fuel_type  \
# 0              Maruti Alto Std         120000  2012     120000    Petrol
# 1            Hyundai Grand i10         550000  2016      20000    Petrol
# 2             Hyundai i20 Asta         215000  2010      60000    Petrol
# 3              Maruti Alto K10         225999  2012      37000    Petrol
# 4      Ford Ecosport 2015-2021         570000  2015      30000    Diesel
# ...                        ...            ...   ...        ...       ...
# 19969    Toyota Platinum Etios         650000  2017      69480    Diesel
# 19970       Maruti Ertiga BSIV         925000  2019      18000    Petrol
# 19971          Skoda Rapid 1.5         425000  2015      67000    Diesel
# 19972       Mahindra XUV500 W6        1225000  2016    3800000    Diesel
# 19973        Honda City i-VTEC        1200000  2019      13000    Petrol
#
#       transmission_type  company
# 0                Manual   Maruti
# 1                Manual  Hyundai
# 2                Manual  Hyundai
# 3                Manual   Maruti
# 4                Manual     Ford
# ...                 ...      ...
# 19969            Manual      NaN
# 19970            Manual      NaN
# 19971            Manual      NaN
# 19972            Manual      NaN
# 19973         Automatic      NaN
#
# [19974 rows x 7 columns]

# %%
#Downloading Dataset i.e Final Dataset
from google.colab import files
data.to_csv('data.csv') 
files.download('data.csv')

# %%
type(data['selling_price'])
# Out:
# pandas.core.series.Series

# %%
fig = plt.figure(figsize=(16,9))
ax = sns.heatmap(data.corr(), cmap='Blues', mask=np.triu(data.corr(), k=1), cbar=False,
                 annot_kws=dict(fontsize=4))
ax.set_facecolor('white')
ax.tick_params(labelsize=5)
plt.show()

# %%
data
# Out:
#                      full_name  selling_price  year  km_driven fuel_type  \
# 0              Maruti Alto Std         120000  2012     120000    Petrol
# 1            Hyundai Grand i10         550000  2016      20000    Petrol
# 2             Hyundai i20 Asta         215000  2010      60000    Petrol
# 3              Maruti Alto K10         225999  2012      37000    Petrol
# 4      Ford Ecosport 2015-2021         570000  2015      30000    Diesel
# ...                        ...            ...   ...        ...       ...
# 19969    Toyota Platinum Etios         650000  2017      69480    Diesel
# 19970       Maruti Ertiga BSIV         925000  2019      18000    Petrol
# 19971          Skoda Rapid 1.5         425000  2015      67000    Diesel
# 19972       Mahindra XUV500 W6        1225000  2016    3800000    Diesel
# 19973        Honda City i-VTEC        1200000  2019      13000    Petrol
#
#       transmission_type  company
# 0                Manual   Maruti
# 1                Manual  Hyundai
# 2                Manual  Hyundai
# 3                Manual   Maruti
# 4                Manual     Ford
# ...                 ...      ...
# 19969            Manual      NaN
# 19970            Manual      NaN
# 19971            Manual      NaN
# 19972            Manual      NaN
# 19973         Automatic      NaN
#
# [19974 rows x 7 columns]

# %% [markdown]
# #Model

# %%
X=data.drop(columns='selling_price')
y=data['selling_price']

# %%
X
# Out:
#                      full_name  year  km_driven fuel_type transmission_type  \
# 0              Maruti Alto Std  2012     120000    Petrol            Manual
# 1            Hyundai Grand i10  2016      20000    Petrol            Manual
# 2             Hyundai i20 Asta  2010      60000    Petrol            Manual
# 3              Maruti Alto K10  2012      37000    Petrol            Manual
# 4      Ford Ecosport 2015-2021  2015      30000    Diesel            Manual
# ...                        ...   ...        ...       ...               ...
# 19969    Toyota Platinum Etios  2017      69480    Diesel            Manual
# 19970       Maruti Ertiga BSIV  2019      18000    Petrol            Manual
# 19971          Skoda Rapid 1.5  2015      67000    Diesel            Manual
# 19972       Mahindra XUV500 W6  2016    3800000    Diesel            Manual
# 19973        Honda City i-VTEC  2019      13000    Petrol         Automatic
#
#        company
# 0       Maruti
# 1      Hyundai
# 2      Hyundai
# 3       Maruti
# 4         Ford
# ...        ...
# 19969      NaN
# 19970      NaN
# 19971      NaN
# 19972      NaN
# 19973      NaN
#
# [19974 rows x 6 columns]

# %%
data['company'].tail(50)
# Out:
# 19924            Honda
# 19925           Maruti
# 19926    Mercedes-Benz
# 19927            Honda
# 19928          Hyundai
# 19929           Toyota
# 19930           Maruti
# 19931           Maruti
# 19932           Maruti
# 19933           Maruti
# 19934       Volkswagen
# 19935             Land
# 19936          Hyundai
# 19937       Volkswagen
# 19938          Hyundai
# 19939           Datsun
# 19940             Tata
# 19941           Toyota
# 19942           Maruti
# 19943          Renault
# 19944           Maruti
# 19945           Maruti
# 19946            Honda
# 19947            Honda
# 19948          Hyundai
# 19949          Renault
# 19950    Mercedes-Benz
# 19951           Maruti
# 19952          Hyundai
# 19953          Hyundai
# 19954           Maruti
# 19955           Toyota
# 19956           Maruti
# 19957            Skoda
# 19958            Honda
# 19959              NaN
# 19960              NaN
# 19961              NaN
# 19962              NaN
# 19963              NaN
# 19964              NaN
# 19965              NaN
# 19966              NaN
# 19967              NaN
# 19968              NaN
# 19969              NaN
# 19970              NaN
# 19971              NaN
# 19972              NaN
# 19973              NaN
# Name: company, dtype: object

# %%
data.drop(data.tail(15).index,inplace = True)

# %%
data
# Out:
#                      full_name  selling_price  year  km_driven fuel_type  \
# 0              Maruti Alto Std         120000  2012     120000    Petrol
# 1            Hyundai Grand i10         550000  2016      20000    Petrol
# 2             Hyundai i20 Asta         215000  2010      60000    Petrol
# 3              Maruti Alto K10         225999  2012      37000    Petrol
# 4      Ford Ecosport 2015-2021         570000  2015      30000    Diesel
# ...                        ...            ...   ...        ...       ...
# 19954      Tata Zest Quadrajet         400000  2016     100000    Diesel
# 19955     Toyota Innova Crysta        2350000  2018      21265    Diesel
# 19956          Maruti Alto 800         275000  2014      44000       CNG
# 19957     Renault KWID Climber         484999  2017      29847    Petrol
# 19958          Maruti Alto 800         313000  2017      12706    Petrol
#
#       transmission_type  company
# 0                Manual   Maruti
# 1                Manual  Hyundai
# 2                Manual  Hyundai
# 3                Manual   Maruti
# 4                Manual     Ford
# ...                 ...      ...
# 19954            Manual   Maruti
# 19955         Automatic   Toyota
# 19956            Manual   Maruti
# 19957         Automatic    Skoda
# 19958            Manual    Honda
#
# [19959 rows x 7 columns]

# %%
data.to_csv('final.csv')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe= OneHotEncoder()
ohe.fit(X[['full_name','company','fuel_type','transmission_type']] )
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['full_name','company','fuel_type','transmission_type']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ambassador Avigo 1800', 'Ambassador Avigo 2000',
#        'Ambassador Classic 1800', ..., 'Volvo XC60 D4', 'Volvo XC60 D5',
#        'Volvo XC90 D5'], dtype=object),
#                                                                             array(['Ambassador', 'Audi', 'BMW', 'Chevrolet', 'DC', 'Daewoo', 'Datsun',
#        'Fiat', 'Fo...
#        'Maruti', 'Maserati', 'Mercedes-AMG', 'Mercedes-Benz', 'Mini',
#        'Mitsubishi', 'Nissan', 'Opel', 'OpelCorsa', 'Porsche', 'Premier',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo', nan],
#       dtype=object),
#                                                                             array(['CNG', 'Diesel', 'Electric', 'LPG', 'Petrol'], dtype=object),
#                                                                             array(['Automatic', 'Manual'], dtype=object)]),
#                                                   ['full_name', 'company',
#                                                    'fuel_type',
#                                                    'transmission_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
ohe.categories_
# Out:
# [array(['Ambassador Avigo 1800', 'Ambassador Avigo 2000',
#         'Ambassador Classic 1800', ..., 'Volvo XC60 D4', 'Volvo XC60 D5',
#         'Volvo XC90 D5'], dtype=object),
#  array(['Ambassador', 'Audi', 'BMW', 'Chevrolet', 'DC', 'Daewoo', 'Datsun',
#         'Fiat', 'Force', 'Ford', 'Honda', 'Hyundai', 'ISUZU', 'Isuzu',
#         'Jaguar', 'Jeep', 'Kia', 'Land', 'Lexus', 'MG', 'Mahindra',
#         'Maruti', 'Maserati', 'Mercedes-AMG', 'Mercedes-Benz', 'Mini',
#         'Mitsubishi', 'Nissan', 'Opel', 'OpelCorsa', 'Porsche', 'Premier',
#         'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo', nan],
#        dtype=object),
#  array(['CNG', 'Diesel', 'Electric', 'LPG', 'Petrol'], dtype=object),
#  array(['Automatic', 'Manual'], dtype=object)]

# %%
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([ 361294.10305831,  550178.97508246,  -19257.35744846, ...,
#         632627.07358271,  704901.36862949, 1303277.93098217])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.47281690562014533

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 681

# %%
scores[np.argmax(scores)]
# Out:
# 0.8733493924646164

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8733493924646164

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Alto Std','Maruti',2021,20000,'Petrol','Manual']],columns=['full_name','company','year','km_driven','fuel_type','transmission_type']))
# Out:
# array([1065011.00241804])
